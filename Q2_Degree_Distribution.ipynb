# %%
library("igraph")
edgelistFile<-read.table("edge_list.txt")
g=graph.data.frame(edgelistFile, directed=T)
# Out:
# Attaching package: ‘igraph’
#
# The following objects are masked from ‘package:stats’:
#
#     decompose, spectrum
#
# The following object is masked from ‘package:base’:
#
#     union

# %%
plot(degree.distribution(g),type='l',main = "Degree Distribution", xlab = "Degree", ylab = "Frequency")
# Out:
# Plot with title “Degree Distribution”

# %%
edgelistFile<-read.table("movie_edge_list.txt")
# Out:
# Error in graph.data.frame(edgelistFile, directed = F): could not find function "graph.data.frame"
# Traceback:

# %%
library("igraph")

# %%
g=graph.data.frame(edgelistFile, directed=F)

# %%
plot(degree.distribution(g),type='l',main = "Degree Distribution", xlab = "Degree", ylab = "Frequency")
# Out:
# Plot with title “Degree Distribution”
