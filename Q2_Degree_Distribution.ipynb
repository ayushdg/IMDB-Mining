# %%
library("igraph")
edgelistFile<-read.table("edge_list.txt")
g=graph.data.frame(edgelistFile, directed=T)
# Out:
# Attaching package: ‘igraph’
#
# The following objects are masked from ‘package:stats’:
#
#     decompose, spectrum
#
# The following object is masked from ‘package:base’:
#
#     union

# %%
plot(degree.distribution(g),type='l',main = "Degree Distribution", xlab = "Degree", ylab = "Frequency")
# Out:
# Plot with title “Degree Distribution”

# %%
# Out:
# [1] "17056"

# %%
gsize(g)
# Out:
# [1] 35408746

# %%
top = c(14492, 111162, 12802, 27230, 32358, 16860, 62697, 107705, 17266, 53187)

# %%
for(a in c(53187)){
    sb =subgraph(g,c(a,neighbors(g,a)))
    print(a)
    print(gsize(sb))
    plot(sb,vertex.size=4, vertex.label.cex=0.1,vertex.color='blue')
}
# Out:
# Warning message in subgraph(g, c(a, neighbors(g, a))):
# “At structural_properties.c:1984 :igraph_subgraph is deprecated from igraph 0.6, use igraph_induced_subgraph instead”
# [1] 53187
# [1] 1636
# Plot with title “”

# %%
V(g)[V(g)$name == '17056' ]
# Out:
# + 1/112913 vertex, named, from 94bf97f:
# [1] 17056

# %%
edges = E(g)

# %%
E(g)[1]
# Out:
# + 1/35408746 edge from 94bf97f (vertex names):
# [1] 1->9760

# %%
g[1,2]
# Out:
# [1] 1

# %%
head(V(g))
# Out:
# + 6/112913 vertices, named, from 94bf97f:
# [1] 1     9760  17056 21507 30758 30760

# %%
head(edges)
# Out:
# + 6/35408746 edges from 94bf97f (vertex names):
# [1] 1    ->9760  9760 ->1     1    ->17056 17056->1     1    ->21507
# [6] 21507->1

# %%
length(edges$weight)
# Out:
# [1] 0
